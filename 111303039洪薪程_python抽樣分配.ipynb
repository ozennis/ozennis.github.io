# %% [markdown]
# <a href="https://colab.research.google.com/github/ozennis/ozennis.github.io/blob/main/111303039%E6%B4%AA%E8%96%AA%E7%A8%8B_python%E6%8A%BD%E6%A8%A3%E5%88%86%E9%85%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

population = np.array([1, 2, 3, 4, 5, 6])

sample_means = []

for _ in range(10000):
    sample = np.random.choice(population, size=3, replace=True)
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=20)
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.title("Sampling Distribution")
plt.show()
